# %%
import pandas as pd

klingt = pd.read_csv('/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/klingt-events-vienna-csv.csv')
venues = pd.read_csv('/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/venues.csv')

print(klingt.head(3))
print(venues.head(3))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 klingt = pd.read_csv('/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/klingt-events-vienna-csv.csv')
#       4 venues = pd.read_csv('/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/venues.csv')
#       6 print(klingt.head(3))
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/klingt-events-vienna-csv.csv'

# %%
perfecto, funcionó. los dos archivos cargaron bien.

ahora el segundo paso — el merge. esto une klingt con venues usando el nombre del venue como llave. escribí esto en la celda siguiente:

```python
venue_map = {
    'alte schmiede': 'Alte Schmiede',
    'echoraum': 'Echoraum',
    'flucc': 'Flucc',
    'wuk': 'WUK',
    'rhiz': 'Rhiz',
    'sargfabrik': 'Sargfabrik',
    'reaktor': 'Reaktor',
    'celeste': 'Celeste',
}

klingt['venue_norm'] = klingt['venue'].map(venue_map).fillna(klingt['venue'])

resultado = klingt.merge(venues[['Venue', 'Bezirk']], 
                         left_on='venue_norm', 
                         right_on='Venue', 
                         how='left')

print(resultado['Bezirk'].isna().sum(), 'sin bezirk')
print(resultado['Bezirk'].notna().sum(), 'con bezirk')
```

esto es solo un subconjunto del venue_map para empezar. ejecutalo y decime qué sale.

# %%
venue_map = {
    'alte schmiede': 'Alte Schmiede',
    'echoraum': 'Echoraum',
    'flucc': 'Flucc',
    'wuk': 'WUK',
    'rhiz': 'Rhiz',
    'sargfabrik': 'Sargfabrik',
    'reaktor': 'Reaktor',
    'celeste': 'Celeste',
}

klingt['venue_norm'] = klingt['venue'].map(venue_map).fillna(klingt['venue'])

resultado = klingt.merge(venues[['Venue', 'Bezirk']], 
                         left_on='venue_norm', 
                         right_on='Venue', 
                         how='left')

print(resultado['Bezirk'].isna().sum(), 'sin bezirk')
print(resultado['Bezirk'].notna().sum(), 'con bezirk')

# %%
bien, 642 de 990 matchean con ese subconjunto pequeño del mapa. ahora agregamos el mapa completo. en la celda siguiente:

```python
venue_map = {
    'alte schmiede': 'Alte Schmiede',
    'althangrund für alle': 'Althangrund für Alle',
    'allerheiligenpark': 'Allerheiligenpark',
    'allerheiligenpark, 1200': 'Allerheiligenpark',
    'arena': 'Arena Wien',
    'ateliertheater': 'Ateliertheater',
    'bezirksmuseum leopoldstadt': 'Bezirksmuseum Leopoldstadt',
    'café stadtbahn wien': 'Café Stadtbahn',
    'celeste': 'Celeste',
    'château rouge': 'Château Rouge',
    'das lot': 'Das LOT',
    'das werk': 'Das Werk',
    'echoraeume': 'Echoraeume',
    'echoraum': 'Echoraum',
    'flucc': 'Flucc',
    'gekko': 'KV.R / Gekko',
    'instituto cervantes': 'Instituto Cervantes Wien',
    'klangtheater mdw': 'Klangtheater Future Art Lab MDW',
    'koje': 'Koje Wien',
    'kunstraum ewigkeitsgasse': 'Kunstraum Ewigkeitsgasse',
    'loop festival & symposium': 'Loop',
    'minciospace': 'Minciospace',
    'odeon': 'Odeon Theater',
    'radio oe1': 'Radio OE1',
    'reaktor': 'Reaktor',
    'replugged': 'Replugged',
    'rhiz': 'Rhiz',
    'salon garnison': 'Salon Garnison',
    'sargfabrik': 'Sargfabrik',
    'schmähfabrik': 'Schmähfabrik',
    'semmelweisklinik': 'Semmelweisklinik',
    'st. ruprecht': 'St. Ruprecht',
    'studio eberhard': 'Studio Eberhard',
    'theater am werk / kabelwerk': 'Theater am Werk (Kabelwerk)',
    'theater am werk / petersplatz': 'Theater am Werk (Petersplatz)',
    'vekks': 'Vekks',
    'wuk': 'WUK',
    'westbahnstudios': 'Westbahnstudios',
    '1bm': '1bm',
    '7stern': '7stern',
    'ail': 'AIL Angewandte',
}

klingt['venue_norm'] = klingt['venue'].map(venue_map).fillna(klingt['venue'])

resultado = klingt.merge(venues[['Venue', 'Bezirk']], 
                         left_on='venue_norm', 
                         right_on='Venue', 
                         how='left')

print(resultado['Bezirk'].isna().sum(), 'sin bezirk')
print(resultado['Bezirk'].notna().sum(), 'con bezirk')
```

# %%
venue_map = {
    'alte schmiede': 'Alte Schmiede',
    'althangrund für alle': 'Althangrund für Alle',
    'allerheiligenpark': 'Allerheiligenpark',
    'allerheiligenpark, 1200': 'Allerheiligenpark',
    'arena': 'Arena Wien',
    'ateliertheater': 'Ateliertheater',
    'bezirksmuseum leopoldstadt': 'Bezirksmuseum Leopoldstadt',
    'café stadtbahn wien': 'Café Stadtbahn',
    'celeste': 'Celeste',
    'château rouge': 'Château Rouge',
    'das lot': 'Das LOT',
    'das werk': 'Das Werk',
    'echoraeume': 'Echoraeume',
    'echoraum': 'Echoraum',
    'flucc': 'Flucc',
    'gekko': 'KV.R / Gekko',
    'instituto cervantes': 'Instituto Cervantes Wien',
    'klangtheater mdw': 'Klangtheater Future Art Lab MDW',
    'koje': 'Koje Wien',
    'kunstraum ewigkeitsgasse': 'Kunstraum Ewigkeitsgasse',
    'loop festival & symposium': 'Loop',
    'minciospace': 'Minciospace',
    'odeon': 'Odeon Theater',
    'radio oe1': 'Radio OE1',
    'reaktor': 'Reaktor',
    'replugged': 'Replugged',
    'rhiz': 'Rhiz',
    'salon garnison': 'Salon Garnison',
    'sargfabrik': 'Sargfabrik',
    'schmähfabrik': 'Schmähfabrik',
    'semmelweisklinik': 'Semmelweisklinik',
    'st. ruprecht': 'St. Ruprecht',
    'studio eberhard': 'Studio Eberhard',
    'theater am werk / kabelwerk': 'Theater am Werk (Kabelwerk)',
    'theater am werk / petersplatz': 'Theater am Werk (Petersplatz)',
    'vekks': 'Vekks',
    'wuk': 'WUK',
    'westbahnstudios': 'Westbahnstudios',
    '1bm': '1bm',
    '7stern': '7stern',
    'ail': 'AIL Angewandte',
}

klingt['venue_norm'] = klingt['venue'].map(venue_map).fillna(klingt['venue'])

resultado = klingt.merge(venues[['Venue', 'Bezirk']], 
                         left_on='venue_norm', 
                         right_on='Venue', 
                         how='left')

print(resultado['Bezirk'].isna().sum(), 'sin bezirk')
print(resultado['Bezirk'].notna().sum(), 'con bezirk')

# %%
987 de 990 — casi perfecto. los 3 sin bezirk son los `mdw` (workshops, ya decidimos que no entran). 

ahora el cruce final. siguiente celda:

```python
# eventos por bezirk en klingt
klingt_bezirk = resultado[resultado['Bezirk'].notna()].groupby('Bezirk').size().reset_index(name='eventos_klingt')

# eventos por bezirk en dataset
dataset = pd.read_csv('/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/dataset.csv')
dataset_bezirk = dataset[~dataset['Bezirk'].isin(['[kein Bezirk]', '[nicht öffentlich]'])].groupby('Bezirk').size().reset_index(name='eventos_dataset')

# financiación MA7 por bezirk en vereine
vereine = pd.read_csv('/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/vereine.csv')
ver_ma7 = vereine[
    (vereine['Foerderung_ref'] == 'MA7') &
    (vereine['Typ'] == 'Beschluss') &
    (~vereine['Bezirk'].isin(['[nicht dokumentiert]']))
].copy()
ver_ma7['Betrag_EUR'] = pd.to_numeric(ver_ma7['Betrag_EUR'], errors='coerce')
fin_bezirk = ver_ma7.groupby('Bezirk')['Betrag_EUR'].sum().reset_index(name='MA7_EUR_total')

# merge de los tres
cruce = klingt_bezirk.merge(dataset_bezirk, on='Bezirk', how='outer')
cruce = cruce.merge(fin_bezirk, on='Bezirk', how='outer')
cruce = cruce.fillna(0)
cruce['Bezirk'] = cruce['Bezirk'].astype(str)
cruce = cruce.sort_values('Bezirk')

print(cruce.to_string(index=False))
```

# %%
# eventos por bezirk en klingt
klingt_bezirk = resultado[resultado['Bezirk'].notna()].groupby('Bezirk').size().reset_index(name='eventos_klingt')

# eventos por bezirk en dataset
dataset = pd.read_csv('/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/dataset.csv')
dataset_bezirk = dataset[~dataset['Bezirk'].isin(['[kein Bezirk]', '[nicht öffentlich]'])].groupby('Bezirk').size().reset_index(name='eventos_dataset')

# financiación MA7 por bezirk en vereine
vereine = pd.read_csv('/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/vereine.csv')
ver_ma7 = vereine[
    (vereine['Foerderung_ref'] == 'MA7') &
    (vereine['Typ'] == 'Beschluss') &
    (~vereine['Bezirk'].isin(['[nicht dokumentiert]']))
].copy()
ver_ma7['Betrag_EUR'] = pd.to_numeric(ver_ma7['Betrag_EUR'], errors='coerce')
fin_bezirk = ver_ma7.groupby('Bezirk')['Betrag_EUR'].sum().reset_index(name='MA7_EUR_total')

# merge de los tres
cruce = klingt_bezirk.merge(dataset_bezirk, on='Bezirk', how='outer')
cruce = cruce.merge(fin_bezirk, on='Bezirk', how='outer')
cruce = cruce.fillna(0)
cruce['Bezirk'] = cruce['Bezirk'].astype(str)
cruce = cruce.sort_values('Bezirk')

print(cruce.to_string(index=False))

# %%
klingt_bezirk['Bezirk'] = klingt_bezirk['Bezirk'].astype(str)
dataset_bezirk['Bezirk'] = dataset_bezirk['Bezirk'].astype(str)
fin_bezirk['Bezirk'] = fin_bezirk['Bezirk'].astype(str)

# %%
klingt_bezirk['Bezirk'] = klingt_bezirk['Bezirk'].astype(str)
dataset_bezirk['Bezirk'] = dataset_bezirk['Bezirk'].astype(str)
fin_bezirk['Bezirk'] = fin_bezirk['Bezirk'].astype(str)

cruce = klingt_bezirk.merge(dataset_bezirk, on='Bezirk', how='outer')
cruce = cruce.merge(fin_bezirk, on='Bezirk', how='outer')
cruce = cruce.fillna(0)
cruce = cruce.sort_values('Bezirk')

print(cruce.to_string(index=False))

# %%
klingt_bezirk['Bezirk'] = klingt_bezirk['Bezirk'].apply(lambda x: str(int(float(x))) if str(x) != 'nan' else x)
dataset_bezirk['Bezirk'] = dataset_bezirk['Bezirk'].astype(str)
fin_bezirk['Bezirk'] = fin_bezirk['Bezirk'].apply(lambda x: str(int(float(x))) if str(x) != 'nan' else x)

# %%
klingt_bezirk['Bezirk'] = klingt_bezirk['Bezirk'].apply(lambda x: str(int(float(x))) if str(x) != 'nan' else x)
dataset_bezirk['Bezirk'] = dataset_bezirk['Bezirk'].astype(str)
fin_bezirk['Bezirk'] = fin_bezirk['Bezirk'].apply(lambda x: str(int(float(x))) if str(x) != 'nan' else x)

cruce = klingt_bezirk.merge(dataset_bezirk, on='Bezirk', how='outer')
cruce = cruce.merge(fin_bezirk, on='Bezirk', how='outer')
cruce = cruce.fillna(0)
cruce = cruce.sort_values('Bezirk')

print(cruce.to_string(index=False))

# %%
import pandas as pd

# %%
vereine = pd.read_csv('vereine.csv')
venues = pd.read_csv('venues.csv')
dataset = pd.read_csv('dataset.csv')
klingt = pd.read_csv('klingt.csv')

# %%
print(dataset.shape)
print(venues.shape)
print(vereine.shape)
print(klingt.shape)

# %%
dataset_bezirk = dataset.groupby('Bezirk').size().reset_index(name='eventos_dataset')

# %%
print(dataset_bezirk)

# %%
venue_map = {
    'alte schmiede': 'Alte Schmiede',
    'althangrund für alle': 'Althangrund für Alle',
    'allerheiligenpark': 'Allerheiligenpark',
    'allerheiligenpark, 1200': 'Allerheiligenpark',
    'arena': 'Arena Wien',
    'ateliertheater': 'Ateliertheater',
    'bezirksmuseum leopoldstadt': 'Bezirksmuseum Leopoldstadt',
    'café stadtbahn wien': 'Café Stadtbahn',
    'celeste': 'Celeste',
    'château rouge': 'Château Rouge',
    'das lot': 'Das LOT',
    'das werk': 'Das Werk',
    'echoraeume': 'Echoraeume',
    'echoraum': 'Echoraum',
    'flucc': 'Flucc',
    'gekko': 'KV.R / Gekko',
    'instituto cervantes': 'Instituto Cervantes Wien',
    'klangtheater mdw': 'Klangtheater Future Art Lab MDW',
    'koje': 'Koje Wien',
    'kunstraum ewigkeitsgasse': 'Kunstraum Ewigkeitsgasse',
    'loop festival & symposium': 'Loop',
    'minciospace': 'Minciospace',
    'odeon': 'Odeon Theater',
    'radio oe1': 'Radio OE1',
    'reaktor': 'Reaktor',
    'replugged': 'Replugged',
    'rhiz': 'Rhiz',
    'salon garnison': 'Salon Garnison',
    'sargfabrik': 'Sargfabrik',
    'schmähfabrik': 'Schmähfabrik',
    'semmelweisklinik': 'Semmelweisklinik',
    'st. ruprecht': 'St. Ruprecht',
    'studio eberhard': 'Studio Eberhard',
    'theater am werk / kabelwerk': 'Theater am Werk (Kabelwerk)',
    'theater am werk / petersplatz': 'Theater am Werk (Petersplatz)',
    'vekks': 'Vekks',
    'wuk': 'WUK',
    'westbahnstudios': 'Westbahnstudios',
    '1bm': '1bm',
    '7stern': '7stern',
    'ail': 'AIL Angewandte',
}

klingt['venue_norm'] = klingt['venue'].map(venue_map).fillna(klingt['venue'])

resultado = klingt.merge(venues[['Venue', 'Bezirk']], 
                         left_on='venue_norm', 
                         right_on='Venue', 
                         how='left')

print(resultado['Bezirk'].isna().sum(), 'sin bezirk')
print(resultado['Bezirk'].notna().sum(), 'con bezirk')

# %%
klingt_bezirk = resultado[resultado['Bezirk'].notna()].groupby('Bezirk').size().reset_index(name='eventos_klingt')

# %%
print(klingt_bezirk)

# %%
resultado['Bezirk'] = resultado['Bezirk'].dropna().apply(lambda x: str(int(x)))

# %%
print(klingt_bezirk)

# %%
ejecutá esto en una celda nueva para ver qué tipo tiene Bezirk en resultado:

```python
print(resultado['Bezirk'].dtype)
print(resultado['Bezirk'].head())
```

# %%
print(resultado['Bezirk'].dtype)
print(resultado['Bezirk'].head())

# %%
print(venues['Bezirk'].unique())

# %%
venues['Bezirk'] = venues['Bezirk'].astype(str)

# %%
print(venues['Bezirk'].unique())

# %%
resultado['Bezirk'] = resultado['Bezirk'].dropna().apply(lambda x: str(int(x)))

# %%
print(klingt_bezirk)

# %%
el problema es que `klingt_bezirk` ya estaba creado antes del fix. tenés que volver a correr la línea que la crea:

```python
klingt_bezirk = resultado[resultado['Bezirk'].notna()].groupby('Bezirk').size().reset_index(name='eventos_klingt')
print(klingt_bezirk)
```

# %%
klingt_bezirk = resultado[resultado['Bezirk'].notna()].groupby('Bezirk').size().reset_index(name='eventos_klingt')
print(klingt_bezirk)

# %%
vereine = pd.read_csv('/Users/nicolekiruka/Desktop/vorstudie/musikoekosysteme-wien/vereine.csv')
ver_ma7 = vereine[
    (vereine['Foerderung_ref'] == 'MA7') &
    (vereine['Typ'] == 'Beschluss') &
    (~vereine['Bezirk'].isin(['[nicht dokumentiert]']))
].copy()
ver_ma7['Betrag_EUR'] = pd.to_numeric(ver_ma7['Betrag_EUR'], errors='coerce')
fin_bezirk = ver_ma7.groupby('Bezirk')['Betrag_EUR'].sum().reset_index(name='MA7_EUR_total')

# %%
print(fin_bezirk)

# %%
print(ver_ma7[ver_ma7['Bezirk'] == '3'][['Verein', 'Betrag_EUR', 'Jahr']])

# %%
cruce = dataset_bezirk.merge(klingt_bezirk, on='Bezirk', how='outer')

# %%
Claude respondió: print(cruce)print(cruce)

# %%
print(cruce)print(cruce)

# %%
print(cruce)

# %%
cruce = cruce.merge(???, on='Bezirk', how='outer')

# %%
cruce = cruce.merge(fin_bezirk, on='Bezirk', how='outer')

# %%
print(cruce)

# %%
venues_raw = pd.read_csv('venues_raw.csv')
venues_21 = pd.read_csv('venues21_5.csv')
print(venues_raw.shape)
print(venues_21.shape)

# %%
venues_raw = pd.read_csv('venues_raw.csv')
venues_21 = pd.read_csv('venues21_5.csv')
print(venues_raw.shape)
print(venues_21.shape)

# %%
venues_raw = pd.read_csv('venues_raw.csv') 
venues_21 = pd.read_csv('venues_21.csv') 
venuesnoidea = pd.read_csv('venuesnoidea.csv') 
print(venues_raw.shape) 
print(venues_21.shape)
print(venuesnoidea.shape)

# %%
venues_raw = pd.read_csv('venues_raw.csv') 
venues_21 = pd.read_csv('venues_21.csv') 
venuesnoidea = pd.read_csv('venues_noidea.csv') 
print(venues_raw.shape) 
print(venues_21.shape)
print(venues_noidea.shape)

# %%
venues_raw = pd.read_csv('venues_raw.csv') 
venues_21 = pd.read_csv('venues_21.csv') 
venues_noidea = pd.read_csv('venues_noidea.csv') 
print(venues_raw.shape) 
print(venues_21.shape)
print(venues_noidea.shape)

# %%
print(venues_raw.columns.tolist())
print(venues_21.columns.tolist())
print(venuesnoidea.columns.tolist())

# %%
en_noidea = set(venuesnoidea['Venue'].str.strip())
en_21 = set(venues_21['Venue'].str.strip())
solo_en_noidea = en_noidea - en_21
print(solo_en_noidea)

# %%
en_venues= set(venues['Venue'].str.strip()) en_21 = set(venues_21['Venue'].str.strip()) solo_en_venues = en_venues - en_21 print(solo_en_venues)

# %%
en_venues = set(venues['Venue'].str.strip())
en_21 = set(venues_21['Venue'].str.strip())
solo_en_venues = en_venues - en_21
print(solo_en_venues)

# %%
import pandas as pd
vereine = pd.read_csv('vereine.csv')
print(vereine['Bezirk'].isna().sum(), "vacíos de", len(vereine), "total")
print(vereine['Bezirk'].value_counts(dropna=False).head(10))

# %%
import pandas as pd

# %%
dataset = pd.read_csv('dataset.csv')
venues = pd.read_csv('vereine_clean.csv')
vereine = pd.read_csv('vereine_clean.csv')

# %%
dataset = pd.read_csv('dataset.csv')
venues = pd.read_csv('vereine_clean.csv')
vereine = pd.read_csv('vereine_clean.csv')

# %%
dataset = pd.read_csv('dataset.csv')
venues = pd.read_csv('venues.csv')
vereine = pd.read_csv('vereine.csv')

# %%
dataset = pd.read_csv('dataset.csv')
venues = pd.read_csv('venues.csv')
vereine = pd.read_csv('vereine.csv')

# %%
**celda 3 — tabla bezirk eventos**
```python
eventos_bezirk = dataset.groupby('Bezirk').size().reset_index(name='n_eventos')
print(eventos_bezirk.sort_values('n_eventos', ascending=False).to_string())
```

# %%
eventos_bezirk = dataset.groupby('Bezirk').size().reset_index(name='n_eventos')
print(eventos_bezirk.sort_values('n_eventos', ascending=False).to_string())

# %%
fin_bezirk = vereine[vereine['Typ']=='Beschluss'].groupby('Bezirk')['Betrag_EUR'].sum().reset_index()
fin_bezirk.columns = ['Bezirk', 'total_EUR']
fin_bezirk['Betrag_EUR'] = fin_bezirk['total_EUR'].astype(int)
print(fin_bezirk.sort_values('total_EUR', ascending=False).to_string())

# %%
cruce = eventos_bezirk.merge(fin_bezirk[['Bezirk','total_EUR']], on='Bezirk', how='outer').fillna(0)
cruce['total_EUR'] = cruce['total_EUR'].astype(int)
cruce = cruce.sort_values('n_eventos', ascending=False)
print(cruce.to_string())

# %%
import pandas as pd
df = pd.read_csv('dataset.csv', sep=';')
vr = pd.read_csv('vereine.csv', sep=';')
vr_b = vr[vr['Typ']=='Beschluss'].copy()
vr_b['Betrag_EUR'] = pd.to_numeric(vr_b['Betrag_EUR'], errors='coerce')
events = df[df['Bezirk'].apply(lambda x: str(x).isdigit())].groupby('Bezirk').size().reset_index(name='Eventos')
funding = vr_b.groupby('Bezirk')['Betrag_EUR'].sum().reset_index(name='EUR')
cruce = pd.merge(events, funding, on='Bezirk', how='outer').fillna(0)
cruce['Bezirk'] = cruce['Bezirk'].astype(str)
cruce = cruce.sort_values('Eventos', ascending=False)
print(cruce.to_string())

# %%
print(vr.columns.tolist())

# %%
vr = pd.read_csv('vereine.csv', sep='\t')

# %%
print(df.columns.tolist())

# %%
import pandas as pd

df = pd.read_csv('dataset.csv', sep='\t', usecols=range(10))
vr = pd.read_csv('vereine.csv', sep='\t')

vr_b = vr[vr['Typ']=='Beschluss'].copy()
vr_b['Betrag_EUR'] = pd.to_numeric(vr_b['Betrag_EUR'], errors='coerce')

events = df[df['Bezirk'].apply(lambda x: str(x).isdigit())].groupby('Bezirk').size().reset_index(name='Eventos')
funding = vr_b.groupby('Bezirk')['Betrag_EUR'].sum().reset_index(name='EUR')

cruce = pd.merge(events, funding, on='Bezirk', how='outer').fillna(0)
cruce['Bezirk'] = cruce['Bezirk'].astype(str)
cruce = cruce.sort_values('Eventos', ascending=False)
print(cruce.to_string())

# %%
print(df.columns.tolist())

# %%
# unir dataset con vereine por Verein + Bezirk del evento
merged = pd.merge(df, vr_b, on='Verein', how='left')
cruce2 = merged.groupby('Bezirk_x').agg(
    Eventos=('Event_Name', 'count'),
    EUR=('Betrag_EUR', 'sum')
).reset_index().rename(columns={'Bezirk_x': 'Bezirk'})
cruce2 = cruce2[cruce2['Bezirk'].apply(lambda x: str(x).isdigit())]
cruce2 = cruce2.sort_values('Eventos', ascending=False)
print(cruce2.to_string())

# %%
vr_total = vr_b.groupby('Verein')['Betrag_EUR'].sum().reset_index(name='EUR_total')
merged2 = pd.merge(df, vr_total, on='Verein', how='left')
cruce3 = merged2.groupby('Bezirk').agg(
    Eventos=('Event_Name', 'count'),
    EUR=('EUR_total', 'sum')
).reset_index()
cruce3 = cruce3[cruce3['Bezirk'].apply(lambda x: str(x).isdigit())]
cruce3 = cruce3.sort_values('Eventos', ascending=False)
print(cruce3.to_string())

# %%
vr_total = vr_b.groupby('Verein')['Betrag_EUR'].sum().reset_index(name='EUR_total')
merged3 = pd.merge(df, vr_total, on='Verein', how='left')
cruce4 = merged3[merged3['Bezirk'].apply(lambda x: str(x).isdigit())]
cruce4 = cruce4.groupby(['Bezirk', 'Verein']).agg(
    n_eventos=('Event_Name', 'count'),
    EUR_total=('EUR_total', 'first')
).reset_index()
cruce4 = cruce4.sort_values(['Bezirk', 'n_eventos'], ascending=[True, False])
print(cruce4.to_string())

# %%
import plotly.graph_objects as go

cruce_plot = cruce3[cruce3['Bezirk'].apply(lambda x: str(x).isdigit())].copy()
cruce_plot['Bezirk'] = cruce_plot['Bezirk'].astype(str)
cruce_plot = cruce_plot.sort_values('Eventos', ascending=False)

fig = go.Figure()
fig.add_trace(go.Bar(name='Eventos', x=cruce_plot['Bezirk'], y=cruce_plot['Eventos']))
fig.add_trace(go.Bar(name='EUR (miles)', x=cruce_plot['Bezirk'], y=cruce_plot['EUR']/1000))

fig.update_layout(
    barmode='group',
    title='Eventos y financiación por Bezirk',
    xaxis_title='Bezirk',
    yaxis_title='Valor'
)
fig.show()

# %%
# !pip install plotly

# %%
import plotly.graph_objects as go

cruce_plot = cruce3[cruce3['Bezirk'].apply(lambda x: str(x).isdigit())].copy()
cruce_plot['Bezirk'] = cruce_plot['Bezirk'].astype(str)
cruce_plot = cruce_plot.sort_values('Eventos', ascending=False)

fig = go.Figure()
fig.add_trace(go.Bar(name='Eventos', x=cruce_plot['Bezirk'], y=cruce_plot['Eventos']))
fig.add_trace(go.Bar(name='EUR (miles)', x=cruce_plot['Bezirk'], y=cruce_plot['EUR']/1000))

fig.update_layout(
    barmode='group',
    title='Eventos y financiación por Bezirk',
    xaxis_title='Bezirk',
    yaxis_title='Valor'
)
fig.show()

# %%
fig.write_html('/tmp/bezirk_chart.html')
print("guardado en /tmp/bezirk_chart.html")

# %%
print(cruce3.head())

# %%
fig.write_html('bezirk_chart.html')
print("listo")

# %%
fig2 = go.Figure()
fig2.add_trace(go.Bar(name='Veranstaltungen', x=cruce_plot['Bezirk'], y=cruce_plot['Eventos']))
fig2.add_trace(go.Bar(name='Förderung (Tsd. EUR)', x=cruce_plot['Bezirk'], y=cruce_plot['EUR']/1000))

fig2.update_layout(
    barmode='group',
    title='Veranstaltungen und Förderung nach Bezirk',
    xaxis_title='Bezirk',
    yaxis_title='Wert'
)
fig2.write_html('bezirk_chart_de.html')
print("listo")

# %%
from plotly.subplots import make_subplots

fig3 = make_subplots(specs=[[{"secondary_y": True}]])

fig3.add_trace(
    go.Bar(name='Veranstaltungen', x=cruce_plot['Bezirk'], y=cruce_plot['Eventos'], marker_color='steelblue'),
    secondary_y=False
)
fig3.add_trace(
    go.Bar(name='Förderung (Tsd. EUR)', x=cruce_plot['Bezirk'], y=cruce_plot['EUR']/1000, marker_color='tomato', opacity=0.7),
    secondary_y=True
)

fig3.update_layout(
    barmode='group',
    title='Veranstaltungen und Förderung nach Bezirk',
    xaxis_title='Bezirk'
)
fig3.update_yaxes(title_text='Veranstaltungen', secondary_y=False)
fig3.update_yaxes(title_text='Förderung (Tsd. EUR)', secondary_y=True)

fig3.write_html('bezirk_chart_dual.html')
print("listo")

# %%
fig3.write_image('bezirk_chart_dual.png', width=1200, height=600)
print("listo")

# %%
# !pip install kaleido

# %%
fig3.write_image('bezirk_chart_dual.png', width=1200, height=600)
print("listo")

# %%
 $ pip install --upgrade kaleido

# %%
pip install --upgrade kaleido

# %%
fig3.write_image('bezirk_chart_dual.png', width=1200, height=600)
print("listo")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 fig3.write_image('bezirk_chart_dual.png', width=1200, height=600)
#       2 print("listo")
#
# NameError: name 'fig3' is not defined

# %%
fig3.write_image('bezirk_chart_dual.png', width=1200, height=600)
print("listo")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fig3.write_image('bezirk_chart_dual.png', width=1200, height=600)
#       2 print("listo")
#
# NameError: name 'fig3' is not defined

# %%
from plotly.subplots import make_subplots

fig3 = make_subplots(specs=[[{"secondary_y": True}]])

fig3.add_trace(
    go.Bar(name='Veranstaltungen', x=cruce_plot['Bezirk'], y=cruce_plot['Eventos'], marker_color='steelblue'),
    secondary_y=False
)
fig3.add_trace(
    go.Bar(name='Förderung (Tsd. EUR)', x=cruce_plot['Bezirk'], y=cruce_plot['EUR']/1000, marker_color='tomato', opacity=0.7),
    secondary_y=True
)

fig3.update_layout(
    barmode='group',
    title='Veranstaltungen und Förderung nach Bezirk',
    xaxis_title='Bezirk'
)
fig3.update_yaxes(title_text='Veranstaltungen', secondary_y=False)
fig3.update_yaxes(title_text='Förderung (Tsd. EUR)', secondary_y=True)

fig3.write_html('bezirk_chart_dual.html')
print("listo")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 6
#       1 from plotly.subplots import make_subplots
#       3 fig3 = make_subplots(specs=[[{"secondary_y": True}]])
#       5 fig3.add_trace(
# ----> 6     go.Bar(name='Veranstaltungen', x=cruce_plot['Bezirk'], y=cruce_plot['Eventos'], marker_color='steelblue'),
#       7     secondary_y=False
#       8 )
#       9 fig3.add_trace(
#      10     go.Bar(name='Förderung (Tsd. EUR)', x=cruce_plot['Bezirk'], y=cruce_plot['EUR']/1000, marker_color='tomato', opacity=0.7),
#      11     secondary_y=True
#      12 )
#      14 fig3.update_layout(
#      15     barmode='group',
#      16     title='Veranstaltungen und Förderung nach Bezirk',
#      17     xaxis_title='Bezirk'
#      18 )
#
# NameError: name 'go' is not defined

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
df = pd.read_csv('dataset.csv', sep=';')
vr = pd.read_csv('vereine.csv', sep='\t')
vr_b = vr[vr['Typ']=='Beschluss'].copy()
vr_b['Betrag_EUR'] = pd.to_numeric(vr_b['Betrag_EUR'], errors='coerce')

# %%
vr_total = vr_b.groupby('Verein')['Betrag_EUR'].sum().reset_index(name='EUR_total')
merged3 = pd.merge(df, vr_total, on='Verein', how='left')
cruce3 = merged3.groupby('Bezirk').agg(
    Eventos=('Event_Name', 'count'),
    EUR=('EUR_total', 'sum')
).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/_7/kcqg1bq52wzckdt6sxny0dym0000gn/T/ipykernel_5898/4217195489.py in ?()
#       1 vr_total = vr_b.groupby('Verein')['Betrag_EUR'].sum().reset_index(name='EUR_total')
# ----> 2 merged3 = pd.merge(df, vr_total, on='Verein', how='left')
#       3 cruce3 = merged3.groupby('Bezirk').agg(
#       4     Eventos=('Event_Name', 'count'),
#       5     EUR=('EUR_total', 'sum')
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/core/reshape/merge.py in ?(self)
#    1307                     if lk is not None:
#    1308                         # Then we're either Hashable or a wrong-length arraylike,
#    1309                         #  the latter of which will raise
#    1310                         lk = cast(Hashable, lk)
# -> 1311                         left_keys.append(left._get_label_or_level_values(lk))
#    1312                         join_names.append(lk)
#    1313                     else:
#    1314                         # work-around for merge_asof(left_index=True)
#
# ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/core/generic.py in ?(self, key, axis)
#    1910             values = self.xs(key, axis=other_axes[0])._values
#    1911         elif self._is_level_reference(key, axis=axis):
#    1912             values = self.axes[axis].get_level_values(key)._values
#    1913         else:
# -> 1914             raise KeyError(key)
#    1915
#    1916         # Check for duplicates
#    1917         if values.ndim > 1:
#
# KeyError: 'Verein'

# %%
print(df.columns.tolist())
# Out:
# ['Datum\tVenue\tEvent_Name\tEvent_Typ\tBezirk\tKuenstler:innen\tVeranstalter\tVerein\tFoerderung_ref\tQuelle\tColumn\tColumn2\tColumn3\tColumn4\tColumn5\tColumn6']

# %%
df = pd.read_csv('dataset.csv', sep='\t')

# %%
vr_total = vr_b.groupby('Verein')['Betrag_EUR'].sum().reset_index(name='EUR_total')
merged3 = pd.merge(df, vr_total, on='Verein', how='left')
cruce3 = merged3.groupby('Bezirk').agg(
    Eventos=('Event_Name', 'count'),
    EUR=('EUR_total', 'sum')
).reset_index()

# %%
cruce_plot = cruce3[cruce3['Bezirk'].apply(lambda x: str(x).isdigit())].copy()
cruce_plot['Bezirk'] = cruce_plot['Bezirk'].astype(str)
cruce_plot = cruce_plot.sort_values('Eventos', ascending=False)

fig3 = make_subplots(specs=[[{"secondary_y": True}]])
fig3.add_trace(go.Bar(name='Veranstaltungen', x=cruce_plot['Bezirk'], y=cruce_plot['Eventos'], marker_color='steelblue'), secondary_y=False)
fig3.add_trace(go.Bar(name='Förderung (Tsd. EUR)', x=cruce_plot['Bezirk'], y=cruce_plot['EUR']/1000, marker_color='tomato', opacity=0.7), secondary_y=True)
fig3.update_layout(barmode='group', title='Veranstaltungen und Förderung nach Bezirk', xaxis_title='Bezirk')
fig3.update_yaxes(title_text='Veranstaltungen', secondary_y=False)
fig3.update_yaxes(title_text='Förderung (Tsd. EUR)', secondary_y=True)

# %%
fig3.write_html('bezirk_chart_dual.html')
fig3.write_image('bezirk_chart_dual.png', width=1200, height=600)
print("listo")
# Out:
# listo

# %%
import os
print(os.path.exists('bezirk_chart_dual.png'))
print(os.path.exists('bezirk_chart_dual.html'))
# Out:
# True
# True

# %%
vr_b['Jahr'] = pd.to_numeric(vr_b['Jahr'], errors='coerce')
por_año = vr_b.groupby('Jahr')['Betrag_EUR'].sum().reset_index(name='EUR_total')
print(por_año.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 vr_b['Jahr'] = pd.to_numeric(vr_b['Jahr'], errors='coerce')
#       2 por_año = vr_b.groupby('Jahr')['Betrag_EUR'].sum().reset_index(name='EUR_total')
#       3 print(por_año.to_string())
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
vr = pd.read_csv('vereine.csv', sep='\t')
vr_b = vr[vr['Typ']=='Beschluss'].copy()
vr_b['Betrag_EUR'] = pd.to_numeric(vr_b['Betrag_EUR'], errors='coerce')

# %%
vr_b['Jahr'] = pd.to_numeric(vr_b['Jahr'], errors='coerce')
por_año = vr_b.groupby('Jahr')['Betrag_EUR'].sum().reset_index(name='EUR_total')
print(por_año.to_string())
# Out:
#      Jahr  EUR_total
# 0  2022.0  4991130.0
# 1  2023.0  5574730.0
# 2  2024.0  5826250.0
# 3  2025.0  3675517.0
# 4  2026.0  3280000.0
# 5  2027.0    60000.0

# %%
import plotly.graph_objects as go

fig_años = go.Figure()
fig_años.add_trace(go.Bar(
    x=por_año['Jahr'].astype(int).astype(str),
    y=por_año['EUR_total']/1000,
    marker_color='steelblue'
))
fig_años.update_layout(
    title='Förderung nach Jahr (Tsd. EUR)',
    xaxis_title='Jahr',
    yaxis_title='EUR (Tsd.)'
)
fig_años.write_html('foerderung_pro_jahr.html')
fig_años.write_image('foerderung_pro_jahr.png', width=1200, height=600)
print("listo")
# Out:
# listo

# %%
emp = pd.read_csv('vereine_empfehlungen.csv', sep=';')
print(emp.columns.tolist())
print(emp.shape)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 emp = pd.read_csv('vereine_empfehlungen.csv', sep=';')
#       2 print(emp.columns.tolist())
#       3 print(emp.shape)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 23, saw 2

# %%
emp = pd.read_csv('vereine_empfehlungen.csv', sep='\t')
print(emp.columns.tolist())
print(emp.shape)
# Out:
# ['Verein', 'ZVR-Zahl', 'Bezirk', 'Foerderung_ref', 'Typ', 'Jahr', 'Betrag_EUR', 'Quelle', 'Anmerkungen', 'Unnamed: 9']
# (35, 10)

# %%
emp['Betrag_EUR'] = pd.to_numeric(emp['Betrag_EUR'], errors='coerce')

cruce_emp = pd.merge(
    emp.groupby('Verein')['Betrag_EUR'].sum().reset_index(name='EUR_empfohlen'),
    vr_total.rename(columns={'EUR_total': 'EUR_beschlossen'}),
    on='Verein',
    how='outer'
).fillna(0)

cruce_emp['diferencia'] = cruce_emp['EUR_beschlossen'] - cruce_emp['EUR_empfohlen']
cruce_emp = cruce_emp.sort_values('EUR_empfohlen', ascending=False)
print(cruce_emp.to_string())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 emp['Betrag_EUR'] = pd.to_numeric(emp['Betrag_EUR'], errors='coerce')
#       3 cruce_emp = pd.merge(
#       4     emp.groupby('Verein')['Betrag_EUR'].sum().reset_index(name='EUR_empfohlen'),
# ----> 5     vr_total.rename(columns={'EUR_total': 'EUR_beschlossen'}),
#       6     on='Verein',
#       7     how='outer'
#       8 ).fillna(0)
#      10 cruce_emp['diferencia'] = cruce_emp['EUR_beschlossen'] - cruce_emp['EUR_empfohlen']
#      11 cruce_emp = cruce_emp.sort_values('EUR_empfohlen', ascending=False)
#
# NameError: name 'vr_total' is not defined

# %%
import pandas as pd
vr = pd.read_csv('vereine.csv', sep='\t')
vr_b = vr[vr['Typ']=='Beschluss'].copy()
vr_b['Betrag_EUR'] = pd.to_numeric(vr_b['Betrag_EUR'], errors='coerce')
vr_total = vr_b.groupby('Verein')['Betrag_EUR'].sum().reset_index(name='EUR_total')

# %%
emp['Betrag_EUR'] = pd.to_numeric(emp['Betrag_EUR'], errors='coerce')

cruce_emp = pd.merge(
    emp.groupby('Verein')['Betrag_EUR'].sum().reset_index(name='EUR_empfohlen'),
    vr_total.rename(columns={'EUR_total': 'EUR_beschlossen'}),
    on='Verein',
    how='outer'
).fillna(0)

cruce_emp['diferencia'] = cruce_emp['EUR_beschlossen'] - cruce_emp['EUR_empfohlen']
cruce_emp = cruce_emp.sort_values('EUR_empfohlen', ascending=False)
print(cruce_emp.to_string())
# Out:
#                                                                                                                                                                                                                                                                                                         Verein  EUR_empfohlen  EUR_beschlossen  diferencia
# 41                                                                                                                                                                                      Peer to Peer - Verein zur Förderung und Verbreitung experimenteller Musik, interdisziplinärer Kunstformate und Diskurs       105000.0              0.0   -105000.0
# 44                                                                                                                                                                                                                            RESONANCES+TRANSITIONS - VEREIN ZUR FÖRDERUNG UND VERBREITUNG INNOVATIVER KLÄNGE        57500.0          68000.0     10500.0
# 64                                                                                                                                                                                                                                                                                 Verein für Kunstvermischung        51000.0         153650.0    102650.0
# 28                                                                                                                                                                                                                      Kulturverein Free Music Forum mit dem Zusatz Forum für free Jazz & freie Improvisation        35000.0         145000.0    110000.0
# 89                                                                                                                                                                                                                         small forms - Verein zur Förderung und Verbreitung von zeitgenössischen Musikformen        30000.0         163400.0    133400.0
# 69                                                                                                                                                                                                                                                        Verein für experimentelle improvisierte Musik (VEIM)        30000.0         147000.0    117000.0
# 83                                                                                                                                                                                                                                                    liccht - kulturverein für nischenmusik und populärkultur        25000.0         105000.0     80000.0
# 60                                                                                                                                                                                                                                           The Acousmatic Project - Verein zur Förderung Akusmatischer Musik        25000.0         239500.0    214500.0
# 54                                                                                                                                                                                                                                                    SUENA - Verein zur Förderung und Verbreitung neuer Musik        20000.0          60900.0     40900.0
# 51                                                                                                                                                                                                                                                                           SHIZZLE - Kunst- und Kulturverein        20000.0          70000.0     50000.0
# 38                                                                                                                                                                                                                                     PARKEN, Verein zur Förderung experimenteller Musik im öffentlichem Raum        18000.0          60000.0     42000.0
# 17                                                                                                                                                                                                                                    Floating Sound Gallery Vienna, Verein zur Förderung von Kunst und Kultur        17000.0          48000.0     31000.0
# 5                                                                                                                                                                                                      AUGEND&ADDEND - Verein zur Förderung und Erweiterung transformativer\nKlangräume und queerer Clubkultur        16500.0          17500.0      1000.0
# 37                                                                                                                                                                                                                                       On the Couch - zur Förderung von Kunst und Kultur in der Gesellschaft        14000.0          34000.0     20000.0
# 77                                                                                                                                                                                                                         XOK - Interessensgemeinschaft der experimentellen Musik- und Klangkunstszene\nWiens        12000.0          68000.0     56000.0
# 2                                                                                                                                                                                                                                                                "Vienna.ACTS", Verein zur Förderung von Kunst        10000.0         357000.0    347000.0
# 35                                                                                                                                                                                                                                                                    MOOZAK - VEREIN FÜR EXPERIMENTELLE MUSIK        10000.0          89000.0     79000.0
# 68                                                                                                                                                                                                                                                        Verein für elektroakustische Musik;  Kurztitel VELAK         5000.0              0.0     -5000.0
# 6                                                                                                                                                                                                                                                                                           Alexander Eberhard         3500.0          26500.0     23000.0
# 65                                                                                                                                                                                                                                                                          Verein für elektroakustische Musik         2025.0          11000.0      8975.0
# 14                                                                                                                                                                                                   ExMachinisMusicae: Verein zur Förderung von transdisziplinärer, transkultureller\nund transmedialer Kunst         1500.0          10500.0      9000.0
# 67                                                                                                                                                                                                                                                         Verein für elektroakustische Musik, Kurztitel VELAK            0.0           5000.0      5000.0
# 66                                                                                                                                                                                                                                                          Verein für elektroakustische Musik Kurztitel VELAK            0.0         116300.0    116300.0
# 57                                                                                                                                                                                                                                          Setzkasten, Verein und Werkstatt zur Förderung intermedialer Kunst            0.0          42000.0     42000.0
# 58                                                                                                                                                                                                                                                                          Studio Dan - Verein für Neue Musik            0.0        1067217.0   1067217.0
# 55                                                                                                                                                                                                                      Salam Oida - Verein zur Förderung von Vielfalt in Kunst und Kultur , kurz: Salam\nOida            0.0          25000.0     25000.0
# 62                                                                                                                                                                                                                                                                                  Verein Kulturzentrum FLUCC            0.0         470000.0    470000.0
# 61                                                                                                                                                                                                                                            UNSAFE SOUNDS - Verein zur Verteidigung künstlerischer Grauzonen            0.0         353000.0    353000.0
# 56                                                                                                                                                                                   Sandkasten Syndikat - Verein zur transkulturellen und interdisziplinären\nkünstlerischen Vernetzung und Kulturvermittlung            0.0          18000.0     18000.0
# 59                                                                                                                                                                                                                                                                                    TONSPUR Kunstverein Wien            0.0          73500.0     73500.0
# 63                                                                                                                                                                                                                                                                                Verein Künstlergruppe DYNAMO            0.0          16000.0     16000.0
# 0                                                                                                                                                                                                                           "Sounds Queer?" Feministischer, queerer Verein zur Förderung elektronischer\nMusik            0.0          20000.0     20000.0
# 70                                                                                                                                                                                                                                                                           Verein für vegetabile Klangpraxis            0.0          10000.0     10000.0
# 82                                                                                                                                                                                                                                                                           id/l Agentur für Kunst und Kultur            0.0         316900.0    316900.0
# 92                                                                                                                                                                                                                                                                              tonWerk - Forum für Neue Musik            0.0          14000.0     14000.0
# 91                                                                                                                                                                                                                                              sp ce. Verein zur Förderung von Kunst und Transdisziplinarität            0.0          68500.0     68500.0
# 90                                                                                                                                                                                                                                                           snim - spontanes Netzwerk für improvisierte Musik            0.0          32000.0     32000.0
# 88  rhizome audioart association - Verein zur Verbreitung und Förderung\nzeitgenössischer Ton-, Klang-, Musik-, Geräusch- und Audiokunst sowie von\naudiovisuellen, medienkünstlerischen, bildenden, literarischen und anderen\nkünstlerischen Ausdrucksformen, die sich mit Klang und Musik auseinandersetzen            0.0          31000.0     31000.0
# 87                                                                                                                                                                                                             punctum collective, Verein zur Förderung zeitgenössischer Musik und\ntransmedialer Kunstformate            0.0          56500.0     56500.0
# 86                                                                                                                                                                                                                  moment collective - Verein für experimentelle Musik, audio-visuelle und\nperformative Kuns            0.0         270760.0    270760.0
# 85                                                                                                                                                                                                                                                                                   minciospace Betriebs GmbH            0.0         105000.0    105000.0
# 84                                                                                                                                                                          minciospace - Verein zur Förderung von künstlerischer Entwicklung unter besonderer Berücksichtigung gesellschaftsrelevanter Themen            0.0          13000.0     13000.0
# 81                                                                                                                                                                                                                                                  ensemble N - Verein und Ensemble für zeitgenössische Musik            0.0          62000.0     62000.0
# 71                                                                                                                                                                                                                                 Verein zur Erweiterung des kulturellen und künstlerischen Spektrums (VEKKS)            0.0          73000.0     73000.0
# 80                                                                                                                                                                                                                                                  echoraum Vereinigung zur Förderung der Kulturkommunikation            0.0         871900.0    871900.0
# 79                                                                                                                                                                                                            czirp czirp - experimental and sonic arts. Verein zur Förderung Experimenteller und\nKlang-Kunst            0.0         142900.0    142900.0
# 78                                                                                                                                                                                                                              andother stage - Verein für künstlerische Forschung und transdiszplinäre Kunst            0.0          26000.0     26000.0
# 76                                                                                                                                                                                                                                                                          Wien Modern, Verein für neue Musik            0.0        7745000.0   7745000.0
# 75                                                                                                                                                                                          WUK - Verein zur Schaffung offener Kultur- und Werkstättenhäuser,\nKurzbezeichnung WUK Werkstätten- und Kulturhaus            0.0        2402000.0   2402000.0
# 74                                                                                                                                                                                                                                                                                            Vincent Pongracz            0.0          25000.0     25000.0
# 53                                                                                                                                                                                                                                        STRUMA+IODINE - Verein zur Erweiterung musikalischer Erfahrungsräume            0.0         180300.0    180300.0
# 72                                                                                                                                                                                                                                                         Verein zur Förderung der Neuen Musik im Kirchenraum            0.0          81000.0     81000.0
# 73                                                                                                                                                                                                                                                                          Verein zur Förderung von Subkultur            0.0          24000.0     24000.0
# 47                                                                                                                                                                                                                                           Reboot Jazz - Verein zur Förderung der Weiterentwicklung des Jazz            0.0          70000.0     70000.0
# 52                                                                                                                                                                                                                                                   SISTERS - Verein für queer feministische Kunst und Kultur            0.0         815000.0    815000.0
# 50                                                                                                                                                                                                                                                                       SAMA Kollektiv - Kunst & Kulturverein            0.0          17000.0     17000.0
# 23                                                                                                                                                                                                                                                                                         Jorge Eduardo Gomez            0.0           3000.0      3000.0
# 22                                                                                                                                                                                                                                                                                  Joanna Coleman (KEINPONNY)            0.0           2000.0      2000.0
# 21                                                                                                                                                                                                                                                                                          JazzWerkstatt Wien            0.0         108500.0    108500.0
# 20                                                                                                                                                                                                                                                                               Jazz & Musicclub Porgy & Bess            0.0        2078200.0   2078200.0
# 19                                                                                                                                                                                                                      IMPROPER WALLS – Kulturverein zur Förderung von Kunst und soziokulturellen Initiativen            0.0           3000.0      3000.0
# 18                                                                                                                                                                                                                                                                                           Hjalmar Al-Serori            0.0          35000.0     35000.0
# 16                                                                                                                                                                                                                                         FREIFALL - Verein zur Förderung interdisziplinärer Performancekunst            0.0          11600.0     11600.0
# 15                                                                                                                                                                                                                                                                                            FAM Kulturverein            0.0          93500.0     93500.0
# 13                                                                                                                                                                                                       Engelsharfen+Teufelsgeigen - Verein zur Förderung innovativer musikalischer und performativer Formate            0.0           4000.0      4000.0
# 12                                                                                                                                                                                                                                      ECHOLOT - Kulturverein für transdisziplinäre Kunst & Artistic Research            0.0          16000.0     16000.0
# 11                                                                                                                                                                                                                                                                                              Central Garden            0.0          32500.0     32500.0
# 10                                                                                                                                                                                                                                                                                            Between Feathers            0.0         126500.0    126500.0
# 9                                                                                                                                                                                                                                   Bestand - Verein zur Vermittlung und Förderung von Musik, Kunst und Kultur            0.0          57000.0     57000.0
# 8                                                                                                                                                                                                                                                                                   Antunes de Menezes Melissa            0.0           6000.0      6000.0
# 7                                                                                                                                                                                                            Althangrund - Verein für Kultur-, Wohn- und Sozialraum für Alle, Kurzform:\nAlthangrund für alle!            0.0          25000.0     25000.0
# 4                                                                                                                                                                                                                                                                              AMBITUS - Gruppe für neue Musik            0.0           4000.0      4000.0
# 3                                                                                                                                                                                                                                                                        A M B I T U S – Gruppe für neue Musik            0.0           8000.0      8000.0
# 24                                                                                                                                                                                                                                       Klang.Kunst.Etage - Verein für experimentelle Musik und Kunstprojekte            0.0         128000.0    128000.0
# 25                                                                                                                                                                                                                                                                                             Klangforum Wien            0.0        1140000.0   1140000.0
# 26                                                                                                                                                                                                                                                            Klangmanifeste - Verein für Klang-/Kunst-/Formen            0.0          36100.0     36100.0
# 40                                                                                                                                                                                      Peer to Peer - Verein zur Förderung und Verbreitung experimenteller Musik  interdisziplinärer Kunstformate und Diskurs            0.0          82000.0     82000.0
# 49                                                                                                                                                                                                                                                                                                Regina Fisch            0.0           3000.0      3000.0
# 48                                                                                                                                                                                                                                                      Reconsil - Verein zur Förderung zeitgenössischer Musik            0.0          49000.0     49000.0
# 1                                                                                                                                                                                                                       "Ventil" - Verein zur Freisetzung klanglicher Innovation und Dynamik Kurztitel:\nVenti            0.0          71000.0     71000.0
# 46                                                                                                                                                                                                                                                                                      Rantasa + Rantasa GmbH            0.0         213500.0    213500.0
# 45                                                                                                                                                                                                                                RRRIOT - Verein zur Förderung und Vermittlung feministischen Kulturschaffens            0.0         145500.0    145500.0
# 43                                                                                                                                                                                                                                                                            Platypus - Verein für Neue Musik            0.0         141000.0    141000.0
# 42                                                                                                                                                                                                                                                                                             Pia Maria Palme            0.0           6000.0      6000.0
# 39                                                                                                                                                                                                                                                                             PHACE - Ensemble für neue Musik            0.0        1050000.0   1050000.0
# 27                                                                                                                                                                                                                                                                                Klangwerk - NoMaden im Speck            0.0           1500.0      1500.0
# 36                                                                                                                                                                                                                                          MusicScapes - Musik- & Kunstprojekte im gesellschaftlichen Kontext            0.0          13000.0     13000.0
# 34                                                                                                                                                                                                                    Little Rosies Improvisationsgruppe – Verein für musikalische Improvisation und Zeitgeist            0.0          14000.0     14000.0
# 33                                                                                                                                                                                                                                                                                 Kunstverein das weisse haus            0.0           2500.0      2500.0
# 32                                                                                                                                                                                                                                                                                       Kunstverein KLANGWERK            0.0           3000.0      3000.0
# 31                                                                                                                                                                                                                                                                    Kunst- und Kulturverein Semmelweisklinik            0.0          74500.0     74500.0
# 30                                                                                                                                                                                                                                                                      Kunst- und Kulturverein Akusmonautikum            0.0          18000.0     18000.0
# 29                                                                                                                                                                                                                                                                                           Kulturverein WERK            0.0          59500.0     59500.0
# 93                                                                                                                                                                                                                                               Österreichische Gesellschaft für zeitgenössische Musik (ÖGZM)            0.0          10000.0     10000.0

# %%
print(emp[emp['Verein'].str.contains('Peer to Peer', na=False)][['Verein', 'Jahr', 'Betrag_EUR']])
# Out:
#                                                Verein  Jahr  Betrag_EUR
# 15  Peer to Peer - Verein zur Förderung und Verbre...  2025       55000
# 26  Peer to Peer - Verein zur Förderung und Verbre...  2026       50000

# %%
cruce_año = pd.merge(
    emp.groupby(['Verein', 'Jahr'])['Betrag_EUR'].sum().reset_index(name='EUR_empfohlen'),
    vr_b.groupby(['Verein', 'Jahr'])['Betrag_EUR'].sum().reset_index(name='EUR_beschlossen'),
    on=['Verein', 'Jahr'],
    how='outer'
).fillna(0)
cruce_año['diferencia'] = cruce_año['EUR_beschlossen'] - cruce_año['EUR_empfohlen']
cruce_año = cruce_año[cruce_año['EUR_empfohlen'] > 0].sort_values('Jahr')
print(cruce_año.to_string())
# Out:
#                                                                                                                      Verein        Jahr  EUR_empfohlen  EUR_beschlossen  diferencia
# 8                                                                             "Vienna.ACTS", Verein zur Förderung von Kunst        2025        10000.0         116000.0    106000.0
# 245                                                                liccht - kulturverein für nischenmusik und populärkultur        2025        13000.0          13000.0         0.0
# 192                                                                    Verein für experimentelle improvisierte Musik (VEIM)        2025        15000.0          21000.0      6000.0
# 177                                                                                             Verein für Kunstvermischung        2025        26000.0              0.0    -26000.0
# 165                                                       The Acousmatic Project - Verein zur Förderung Akusmatischer Musik        2025        15000.0          31000.0     16000.0
# 144                                                                SUENA - Verein zur Förderung und Verbreitung neuer Musik        2025        10000.0              0.0    -10000.0
# 132                                                                                       SHIZZLE - Kunst- und Kulturverein        2025        20000.0              0.0    -20000.0
# 264                                     small forms - Verein zur Förderung und Verbreitung von zeitgenössischen Musikformen        2025        15000.0          25000.0     10000.0
# 104  Peer to Peer - Verein zur Förderung und Verbreitung experimenteller Musik, interdisziplinärer Kunstformate und Diskurs        2025        55000.0              0.0    -55000.0
# 95                                                  PARKEN, Verein zur Förderung experimenteller Musik im öffentlichem Raum        2025        12000.0              0.0    -12000.0
# 110                                        RESONANCES+TRANSITIONS - VEREIN ZUR FÖRDERUNG UND VERBREITUNG INNOVATIVER KLÄNGE        2025        30000.0          33500.0      3500.0
# 16                  AUGEND&ADDEND - Verein zur Förderung und Erweiterung transformativer\nKlangräume und queerer Clubkultur        2025        16500.0              0.0    -16500.0
# 86                                                                                 MOOZAK - VEREIN FÜR EXPERIMENTELLE MUSIK        2025         5000.0          11000.0      6000.0
# 19                                                                                                       Alexander Eberhard        2025         3500.0              0.0     -3500.0
# 72                                   Kulturverein Free Music Forum mit dem Zusatz Forum für free Jazz & freie Improvisation        2025        20000.0              0.0    -20000.0
# 47                                                 Floating Sound Gallery Vienna, Verein zur Förderung von Kunst und Kultur        2025         9000.0              0.0     -9000.0
# 90                                                    On the Couch - zur Förderung von Kunst und Kultur in der Gesellschaft        2025         7000.0          15000.0      8000.0
# 38                ExMachinisMusicae: Verein zur Förderung von transdisziplinärer, transkultureller\nund transmedialer Kunst        2025         1500.0              0.0     -1500.0
# 91                                                    On the Couch - zur Förderung von Kunst und Kultur in der Gesellschaft        2026         7000.0           7000.0         0.0
# 246                                                                liccht - kulturverein für nischenmusik und populärkultur        2026        12000.0          12000.0         0.0
# 222                                     XOK - Interessensgemeinschaft der experimentellen Musik- und Klangkunstszene\nWiens        2026        12000.0          24000.0     12000.0
# 193                                                                    Verein für experimentelle improvisierte Musik (VEIM)        2026        15000.0          27000.0     12000.0
# 188                                                                    Verein für elektroakustische Musik;  Kurztitel VELAK        2026         5000.0              0.0     -5000.0
# 178                                                                                             Verein für Kunstvermischung        2026        25000.0              0.0    -25000.0
# 166                                                       The Acousmatic Project - Verein zur Förderung Akusmatischer Musik        2026        10000.0          26000.0     16000.0
# 48                                                 Floating Sound Gallery Vienna, Verein zur Förderung von Kunst und Kultur        2026         8000.0              0.0     -8000.0
# 111                                        RESONANCES+TRANSITIONS - VEREIN ZUR FÖRDERUNG UND VERBREITUNG INNOVATIVER KLÄNGE        2026        27500.0          34500.0      7000.0
# 73                                   Kulturverein Free Music Forum mit dem Zusatz Forum für free Jazz & freie Improvisation        2026        15000.0              0.0    -15000.0
# 105  Peer to Peer - Verein zur Förderung und Verbreitung experimenteller Musik, interdisziplinärer Kunstformate und Diskurs        2026        50000.0              0.0    -50000.0
# 96                                                  PARKEN, Verein zur Förderung experimenteller Musik im öffentlichem Raum        2026         6000.0              0.0     -6000.0
# 87                                                                                 MOOZAK - VEREIN FÜR EXPERIMENTELLE MUSIK        2026         5000.0          11000.0      6000.0
# 145                                                                SUENA - Verein zur Förderung und Verbreitung neuer Musik        2026        10000.0              0.0    -10000.0
# 265                                     small forms - Verein zur Förderung und Verbreitung von zeitgenössischen Musikformen        2026        15000.0          25000.0     10000.0
# 181                                                                                      Verein für elektroakustische Musik  Empfehlung         2025.0              0.0     -2025.0

# %%
from rapidfuzz import process, fuzz

emp_nombres = emp['Verein'].dropna().unique().tolist()
vr_nombres = vr_total['Verein'].dropna().unique().tolist()

matches = []
for nombre in emp_nombres:
    resultado = process.extractOne(nombre, vr_nombres, scorer=fuzz.token_sort_ratio)
    if resultado and resultado[1] >= 80:
        matches.append({'emp_verein': nombre, 'vr_verein': resultado[0], 'score': resultado[1]})

df_matches = pd.DataFrame(matches)
print(df_matches.to_string())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from rapidfuzz import process, fuzz
#       3 emp_nombres = emp['Verein'].dropna().unique().tolist()
#       4 vr_nombres = vr_total['Verein'].dropna().unique().tolist()
#
# ModuleNotFoundError: No module named 'rapidfuzz'

# %%
# !pip install rapidfuzz
# Out:
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (12 kB)
# Downloading rapidfuzz-3.14.5-cp310-cp310-macosx_11_0_arm64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 990.1 kB/s  0:00:01 eta 0:00:01
# Installing collected packages: rapidfuzz
# Successfully installed rapidfuzz-3.14.5
#
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from rapidfuzz import process, fuzz

emp_nombres = emp['Verein'].dropna().unique().tolist()
vr_nombres = vr_total['Verein'].dropna().unique().tolist()

matches = []
for nombre in emp_nombres:
    resultado = process.extractOne(nombre, vr_nombres, scorer=fuzz.token_sort_ratio)
    if resultado and resultado[1] >= 80:
        matches.append({'emp_verein': nombre, 'vr_verein': resultado[0], 'score': resultado[1]})

df_matches = pd.DataFrame(matches)
print(df_matches.to_string())
# Out:
#                                                                                                                 emp_verein                                                                                                               vr_verein       score
# 0                                                 Floating Sound Gallery Vienna, Verein zur Förderung von Kunst und Kultur                                                Floating Sound Gallery Vienna, Verein zur Förderung von Kunst und Kultur  100.000000
# 1                                                        The Acousmatic Project - Verein zur Förderung Akusmatischer Musik                                                       The Acousmatic Project - Verein zur Förderung Akusmatischer Musik  100.000000
# 2                                                                                 MOOZAK - VEREIN FÜR EXPERIMENTELLE MUSIK                                                                                MOOZAK - VEREIN FÜR EXPERIMENTELLE MUSIK  100.000000
# 3                                                                     Verein für experimentelle improvisierte Musik (VEIM)                                                                    Verein für experimentelle improvisierte Musik (VEIM)  100.000000
# 4                                                                                       Verein für elektroakustische Musik                                                                                      Verein für elektroakustische Musik  100.000000
# 5                                                    On the Couch - zur Förderung von Kunst und Kultur in der Gesellschaft                                                   On the Couch - zur Förderung von Kunst und Kultur in der Gesellschaft  100.000000
# 6                                                  PARKEN, Verein zur Förderung experimenteller Musik im öffentlichem Raum                                                 PARKEN, Verein zur Förderung experimenteller Musik im öffentlichem Raum  100.000000
# 7                ExMachinisMusicae: Verein zur Förderung von transdisziplinärer, transkultureller\nund transmedialer Kunst               ExMachinisMusicae: Verein zur Förderung von transdisziplinärer, transkultureller\nund transmedialer Kunst  100.000000
# 8                                                                            "Vienna.ACTS", Verein zur Förderung von Kunst                                                                           "Vienna.ACTS", Verein zur Förderung von Kunst  100.000000
# 9                  AUGEND&ADDEND - Verein zur Förderung und Erweiterung transformativer\nKlangräume und queerer Clubkultur                 AUGEND&ADDEND - Verein zur Förderung und Erweiterung transformativer\nKlangräume und queerer Clubkultur  100.000000
# 10                                                                liccht - kulturverein für nischenmusik und populärkultur                                                                liccht - kulturverein für nischenmusik und populärkultur  100.000000
# 11                                                                                             Verein für Kunstvermischung                                                                                             Verein für Kunstvermischung  100.000000
# 12                                                                SUENA - Verein zur Förderung und Verbreitung neuer Musik                                                                SUENA - Verein zur Förderung und Verbreitung neuer Musik  100.000000
# 13                                     small forms - Verein zur Förderung und Verbreitung von zeitgenössischen Musikformen                                     small forms - Verein zur Förderung und Verbreitung von zeitgenössischen Musikformen  100.000000
# 14                                  Kulturverein Free Music Forum mit dem Zusatz Forum für free Jazz & freie Improvisation                                  Kulturverein Free Music Forum mit dem Zusatz Forum für free Jazz & freie Improvisation  100.000000
# 15  Peer to Peer - Verein zur Förderung und Verbreitung experimenteller Musik, interdisziplinärer Kunstformate und Diskurs  Peer to Peer - Verein zur Förderung und Verbreitung experimenteller Musik  interdisziplinärer Kunstformate und Diskurs   99.574468
# 16                                        RESONANCES+TRANSITIONS - VEREIN ZUR FÖRDERUNG UND VERBREITUNG INNOVATIVER KLÄNGE                                        RESONANCES+TRANSITIONS - VEREIN ZUR FÖRDERUNG UND VERBREITUNG INNOVATIVER KLÄNGE  100.000000
# 17                                                                    Verein für elektroakustische Musik;  Kurztitel VELAK                                                                      Verein für elektroakustische Musik Kurztitel VELAK   99.009901
# 18                                     XOK - Interessensgemeinschaft der experimentellen Musik- und Klangkunstszene\nWiens                                     XOK - Interessensgemeinschaft der experimentellen Musik- und Klangkunstszene\nWiens  100.000000
# 19                                                                                                      Alexander Eberhard                                                                                                      Alexander Eberhard  100.000000
# 20                                                                                       SHIZZLE - Kunst- und Kulturverein                                                                                       SHIZZLE - Kunst- und Kulturverein  100.000000

# %%
match_dict = dict(zip(df_matches['emp_verein'], df_matches['vr_verein']))
emp['Verein_matched'] = emp['Verein'].map(match_dict).fillna(emp['Verein'])

cruce_año = pd.merge(
    emp.groupby(['Verein_matched', 'Jahr'])['Betrag_EUR'].sum().reset_index(name='EUR_empfohlen'),
    vr_b[vr_b['Foerderung_ref']=='MA7'].groupby(['Verein', 'Jahr'])['Betrag_EUR'].sum().reset_index(name='EUR_beschlossen'),
    left_on=['Verein_matched', 'Jahr'],
    right_on=['Verein', 'Jahr'],
    how='left'
).fillna(0)

cruce_año['diferencia'] = cruce_año['EUR_beschlossen'] - cruce_año['EUR_empfohlen']
cruce_año = cruce_año.sort_values('Jahr')
print(cruce_año[['Verein_matched', 'Jahr', 'EUR_empfohlen', 'EUR_beschlossen', 'diferencia']].to_string())
# Out:
#                                                                                                             Verein_matched        Jahr  EUR_empfohlen  EUR_beschlossen  diferencia
# 0                                                                            "Vienna.ACTS", Verein zur Förderung von Kunst        2025          10000         116000.0    106000.0
# 30                                                                liccht - kulturverein für nischenmusik und populärkultur        2025          13000          13000.0         0.0
# 27                                                                    Verein für experimentelle improvisierte Musik (VEIM)        2025          15000          21000.0      6000.0
# 23                                                                                             Verein für Kunstvermischung        2025          26000              0.0    -26000.0
# 21                                                       The Acousmatic Project - Verein zur Förderung Akusmatischer Musik        2025          15000          31000.0     16000.0
# 19                                                                SUENA - Verein zur Förderung und Verbreitung neuer Musik        2025          10000              0.0    -10000.0
# 18                                                                                       SHIZZLE - Kunst- und Kulturverein        2025          20000              0.0    -20000.0
# 32                                     small forms - Verein zur Förderung und Verbreitung von zeitgenössischen Musikformen        2025          15000          25000.0     10000.0
# 14  Peer to Peer - Verein zur Förderung und Verbreitung experimenteller Musik  interdisziplinärer Kunstformate und Diskurs        2025          55000          55000.0         0.0
# 12                                                 PARKEN, Verein zur Förderung experimenteller Musik im öffentlichem Raum        2025          12000              0.0    -12000.0
# 16                                        RESONANCES+TRANSITIONS - VEREIN ZUR FÖRDERUNG UND VERBREITUNG INNOVATIVER KLÄNGE        2025          30000          33500.0      3500.0
# 1                  AUGEND&ADDEND - Verein zur Förderung und Erweiterung transformativer\nKlangräume und queerer Clubkultur        2025          16500              0.0    -16500.0
# 8                                                                                 MOOZAK - VEREIN FÜR EXPERIMENTELLE MUSIK        2025           5000          11000.0      6000.0
# 2                                                                                                       Alexander Eberhard        2025           3500              0.0     -3500.0
# 6                                   Kulturverein Free Music Forum mit dem Zusatz Forum für free Jazz & freie Improvisation        2025          20000              0.0    -20000.0
# 4                                                 Floating Sound Gallery Vienna, Verein zur Förderung von Kunst und Kultur        2025           9000              0.0     -9000.0
# 10                                                   On the Couch - zur Förderung von Kunst und Kultur in der Gesellschaft        2025           7000          15000.0      8000.0
# 3                ExMachinisMusicae: Verein zur Förderung von transdisziplinärer, transkultureller\nund transmedialer Kunst        2025           1500              0.0     -1500.0
# 11                                                   On the Couch - zur Förderung von Kunst und Kultur in der Gesellschaft        2026           7000           7000.0         0.0
# 31                                                                liccht - kulturverein für nischenmusik und populärkultur        2026          12000          12000.0         0.0
# 29                                     XOK - Interessensgemeinschaft der experimentellen Musik- und Klangkunstszene\nWiens        2026          12000          24000.0     12000.0
# 28                                                                    Verein für experimentelle improvisierte Musik (VEIM)        2026          15000          27000.0     12000.0
# 26                                                                      Verein für elektroakustische Musik Kurztitel VELAK        2026           5000          32000.0     27000.0
# 24                                                                                             Verein für Kunstvermischung        2026          25000              0.0    -25000.0
# 22                                                       The Acousmatic Project - Verein zur Förderung Akusmatischer Musik        2026          10000          26000.0     16000.0
# 5                                                 Floating Sound Gallery Vienna, Verein zur Förderung von Kunst und Kultur        2026           8000              0.0     -8000.0
# 17                                        RESONANCES+TRANSITIONS - VEREIN ZUR FÖRDERUNG UND VERBREITUNG INNOVATIVER KLÄNGE        2026          27500          34500.0      7000.0
# 7                                   Kulturverein Free Music Forum mit dem Zusatz Forum für free Jazz & freie Improvisation        2026          15000              0.0    -15000.0
# 15  Peer to Peer - Verein zur Förderung und Verbreitung experimenteller Musik  interdisziplinärer Kunstformate und Diskurs        2026          50000              0.0    -50000.0
# 13                                                 PARKEN, Verein zur Förderung experimenteller Musik im öffentlichem Raum        2026           6000              0.0     -6000.0
# 9                                                                                 MOOZAK - VEREIN FÜR EXPERIMENTELLE MUSIK        2026           5000          11000.0      6000.0
# 20                                                                SUENA - Verein zur Förderung und Verbreitung neuer Musik        2026          10000              0.0    -10000.0
# 33                                     small forms - Verein zur Förderung und Verbreitung von zeitgenössischen Musikformen        2026          15000          25000.0     10000.0
# 25                                                                                      Verein für elektroakustische Musik  Empfehlung           2025              0.0     -2025.0

# %%
import pandas as pd

# %%
import pandas as pd

dataset = pd.read_csv('dataset.csv', sep='\t', usecols=range(10))
klingt = pd.read_csv('klingt.csv', sep='\t', usecols=range(3))
vereine = pd.read_csv('vereine.csv', sep='\t', usecols=range(10))
venues = pd.read_csv('venues.csv', sep=',')

print(dataset.columns.tolist())
print(klingt.columns.tolist())
print(vereine.columns.tolist())
print(venues.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 4
#       1 import pandas as pd
#       3 dataset = pd.read_csv('dataset.csv', sep='\t', usecols=range(10))
# ----> 4 klingt = pd.read_csv('klingt.csv', sep='\t', usecols=range(3))
#       5 vereine = pd.read_csv('vereine.csv', sep='\t', usecols=range(10))
#       6 venues = pd.read_csv('venues.csv', sep=',')
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:155, in CParserWrapper.__init__(self, src, **kwds)
#     152     # error: Cannot determine type of 'names'
#     153     if len(self.names) < len(usecols):  # type: ignore[has-type]
#     154         # error: Cannot determine type of 'names'
# --> 155         self._validate_usecols_names(
#     156             usecols,
#     157             self.names,  # type: ignore[has-type]
#     158         )
#     160 # error: Cannot determine type of 'names'
#     161 self._validate_parse_dates_presence(self.names)  # type: ignore[has-type]
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:988, in ParserBase._validate_usecols_names(self, usecols, names)
#     986 missing = [c for c in usecols if c not in names]
#     987 if len(missing) > 0:
# --> 988     raise ValueError(
#     989         f"Usecols do not match columns, columns expected but not found: "
#     990         f"{missing}"
#     991     )
#     993 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: [0, 1, 2]

# %%
Usecols do not match columns, columns expected but not found: [0, 1, 2]
# Out:
#   Cell In[3], line 1
#     Usecols do not match columns, columns expected but not found: [0, 1, 2]
#             ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

dataset = pd.read_csv('dataset.csv', sep='\t')
klingt = pd.read_csv('klingt.csv', sep='\t')
vereine = pd.read_csv('vereine.csv', sep='\t')
venues = pd.read_csv('venues.csv', sep=',')

print(dataset.columns.tolist())
print(klingt.columns.tolist())
print(vereine.columns.tolist())
print(venues.columns.tolist())
# Out:
# ['Datum', 'Venue', 'Event_Name', 'Event_Typ', 'Bezirk', 'Kuenstler:innen', 'Veranstalter', 'Verein', 'Foerderung_ref', 'Quelle', 'Column', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6']
# ['datum,event_name,venue']
# ['Verein', 'ZVR-Zahl', 'Bezirk', 'Foerderung_ref', 'Typ', 'Jahr', 'Betrag_EUR', 'Quelle', 'Anmerkungen']
# ['Venue', 'Adresse', 'Bezirk', 'Programmprofil', 'Website', 'lat', 'lon', 'Klassifiezierung', 'Anmerkungen', 'Status']

# %%
import pandas as pd

dataset = pd.read_csv('dataset.csv', sep='\t').iloc[:, :10]
klingt = pd.read_csv('klingt.csv', sep=',')
vereine = pd.read_csv('vereine.csv', sep='\t')
venues = pd.read_csv('venues.csv', sep=',')

print(dataset.shape)
print(klingt.shape)
print(vereine.shape)
print(venues.shape)
# Out:
# (369, 10)
# (990, 3)
# (534, 9)
# (75, 10)

# %%
import pandas as pd

dataset = pd.read_csv('dataset.csv', sep='\t', encoding='utf-8-sig')
klingt = pd.read_csv('klingt.org.csv', sep=',', encoding='utf-8-sig')

# normalizar fecha y venue en minúsculas
dataset['venue_norm'] = dataset['Venue'].str.lower().str.strip()
dataset['datum_norm'] = pd.to_datetime(dataset['Datum'], dayfirst=True)

klingt['venue_norm'] = klingt['venue'].str.lower().str.strip()
klingt['datum_norm'] = pd.to_datetime(klingt['datum'], dayfirst=True)

# detectar duplicados
duplicados = pd.merge(
    dataset[['datum_norm', 'venue_norm']],
    klingt[['datum_norm', 'venue_norm']],
    on=['datum_norm', 'venue_norm'],
    how='inner'
)

print(f"duplicados encontrados: {len(duplicados)}")
print(duplicados.head(20))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[6], line 4
#       1 import pandas as pd
#       3 dataset = pd.read_csv('dataset.csv', sep='\t', encoding='utf-8-sig')
# ----> 4 klingt = pd.read_csv('klingt.org.csv', sep=',', encoding='utf-8-sig')
#       6 # normalizar fecha y venue en minúsculas
#       7 dataset['venue_norm'] = dataset['Venue'].str.lower().str.strip()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 7, saw 3

# %%
dataset = pd.read_csv('dataset.csv', sep='\t', encoding='utf-8-sig', on_bad_lines='skip')

# %%
with open('dataset.csv', encoding='utf-8-sig') as f:
    print(f.readline())
    print(f.readline())
# Out:
# Datum	Venue	Event_Name	Event_Typ	Bezirk	Kuenstler:innen	Veranstalter	Verein	Foerderung_ref	Quelle	Column	Column2	Column3	Column4	Column5	Column6
#
# 2022-01-14	Alte Schmiede	Areal, Filip, Malfatti	Konzert	1	Gabriela Areal | Klaus Filip | Radu Malfatti	Alte Schmiede	KUNSTVEREIN WIEN	MA7	https://klingt.org/gro.tgnilk/events/12683/index.html?sid=14298401013344652

# %%
dataset = pd.read_csv('dataset.csv', sep='\t', encoding='utf-8-sig', usecols=['Datum', 'Venue', 'Bezirk'])

# %%
print(dataset.shape)
print(dataset.head(3))
# Out:
# (376, 3)
#         Datum          Venue Bezirk
# 0  2022-01-14  Alte Schmiede      1
# 1  2022-01-15       echoraum     15
# 2  2022-01-18       echoraum     15

# %%
klingt = pd.read_csv('klingt.org.csv', sep=',', encoding='utf-8-sig', usecols=['datum', 'venue'])

dataset['venue_norm'] = dataset['Venue'].str.lower().str.strip()
dataset['datum_norm'] = pd.to_datetime(dataset['Datum'])

klingt['venue_norm'] = klingt['venue'].str.low
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 klingt = pd.read_csv('klingt.org.csv', sep=',', encoding='utf-8-sig', usecols=['datum', 'venue'])
#       3 dataset['venue_norm'] = dataset['Venue'].str.lower().str.strip()
#       4 dataset['datum_norm'] = pd.to_datetime(dataset['Datum'])
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:140, in CParserWrapper.__init__(self, src, **kwds)
#     136 assert self.orig_names is not None
#     137 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     138     self.orig_names
#     139 ):
# --> 140     self._validate_usecols_names(usecols, self.orig_names)
#     142 # error: Cannot determine type of 'names'
#     143 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     144     # error: Cannot determine type of 'names'
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:988, in ParserBase._validate_usecols_names(self, usecols, names)
#     986 missing = [c for c in usecols if c not in names]
#     987 if len(missing) > 0:
# --> 988     raise ValueError(
#     989         f"Usecols do not match columns, columns expected but not found: "
#     990         f"{missing}"
#     991     )
#     993 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['venue', 'datum']

# %%
klingt = pd.read_csv('klingt.org.csv', sep=',', encoding='utf-8-sig', usecols=['Datum', 'Venue'])

klingt['venue_norm'] = klingt['Venue'].str.lower().str.strip()
klingt['datum_norm'] = pd.to_datetime(klingt['Datum'])

dataset['venue_norm'] = dataset['Venue'].str.lower().str.strip()
dataset['datum_norm'] = pd.to_datetime(dataset['Datum'])

duplicados = pd.merge(
    dataset[['datum_norm', 'venue_norm']],
    klingt[['datum_norm', 'venue_norm']],
    on=['datum_norm', 'venue_norm'],
    how='inner'
)

print(f"duplicados encontrados: {len(duplicados)}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 klingt = pd.read_csv('klingt.org.csv', sep=',', encoding='utf-8-sig', usecols=['Datum', 'Venue'])
#       3 klingt['venue_norm'] = klingt['Venue'].str.lower().str.strip()
#       4 klingt['datum_norm'] = pd.to_datetime(klingt['Datum'])
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:140, in CParserWrapper.__init__(self, src, **kwds)
#     136 assert self.orig_names is not None
#     137 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     138     self.orig_names
#     139 ):
# --> 140     self._validate_usecols_names(usecols, self.orig_names)
#     142 # error: Cannot determine type of 'names'
#     143 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     144     # error: Cannot determine type of 'names'
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:988, in ParserBase._validate_usecols_names(self, usecols, names)
#     986 missing = [c for c in usecols if c not in names]
#     987 if len(missing) > 0:
# --> 988     raise ValueError(
#     989         f"Usecols do not match columns, columns expected but not found: "
#     990         f"{missing}"
#     991     )
#     993 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['Venue', 'Datum']

# %%
klingt = pd.read_csv('klingt.org.csv', sep=',', encoding='utf-8-sig')
print(klingt.columns.tolist())
print(klingt.head(2))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 klingt = pd.read_csv('klingt.org.csv', sep=',', encoding='utf-8-sig')
#       2 print(klingt.columns.tolist())
#       3 print(klingt.head(2))
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 7, saw 3

# %%
klingt = pd.read_csv('klingt.org.csv', sep='\t', encoding='utf-8-sig')
print(klingt.columns.tolist())
print(klingt.head(2))
# Out:
# ['Datum', 'Event_Name', 'Venue']
#         Datum                                     Event_Name Venue
# 0  2022-01-10  The Dead Class - A Musical (!) by Wanunu &...   WUK
# 1  2022-01-11  The Dead Class - A Musical (!) by Wanunu &...   WUK

# %%
klingt['venue_norm'] = klingt['Venue'].str.lower().str.strip()
klingt['datum_norm'] = pd.to_datetime(klingt['Datum'])

duplicados = pd.merge(
    dataset[['datum_norm', 'venue_norm']],
    klingt[['datum_norm', 'venue_norm']],
    on=['datum_norm', 'venue_norm'],
    how='inner'
)

print(f"duplicados encontrados: {len(duplicados)}")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 5
#       1 klingt['venue_norm'] = klingt['Venue'].str.lower().str.strip()
#       2 klingt['datum_norm'] = pd.to_datetime(klingt['Datum'])
#       4 duplicados = pd.merge(
# ----> 5     dataset[['datum_norm', 'venue_norm']],
#       6     klingt[['datum_norm', 'venue_norm']],
#       7     on=['datum_norm', 'venue_norm'],
#       8     how='inner'
#       9 )
#      11 print(f"duplicados encontrados: {len(duplicados)}")
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/core/frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/core/indexes/base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/core/indexes/base.py:6261, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6259 if nmissing:
#    6260     if nmissing == len(indexer):
# -> 6261         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6264     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['datum_norm', 'venue_norm'], dtype='object')] are in the [columns]"

# %%
dataset['venue_norm'] = dataset['Venue'].str.lower().str.strip()
dataset['datum_norm'] = pd.to_datetime(dataset['Datum'])

klingt['venue_norm'] = klingt['Venue'].str.lower().str.strip()
klingt['datum_norm'] = pd.to_datetime(klingt['Datum'])

duplicados = pd.merge(
    dataset[['datum_norm', 'venue_norm']],
    klingt[['datum_norm', 'venue_norm']],
    on=['datum_norm', 'venue_norm'],
    how='inner'
)

print(f"duplicados encontrados: {len(duplicados)}")
# Out:
# duplicados encontrados: 93

# %%
klingt['fuente'] = 'klingt'
dataset['fuente'] = 'dataset'

klingt_norm = klingt[['datum_norm', 'venue_norm', 'fuente']].copy()
dataset_norm = dataset[['datum_norm', 'venue_norm', 'Bezirk', 'fuente']].copy()

# quitar de klingt los que ya están en dataset
klingt_sin_dup = klingt_norm.merge(
    dataset[['datum_norm', 'venue_norm']],
    on=['datum_norm', 'venue_norm'],
    how='left',
    indicator=True
).query('_merge == "left_only"').drop(columns='_merge')

print(f"klingt sin duplicados: {len(klingt_sin_dup)}")
print(f"dataset: {len(dataset_norm)}")
print(f"total combinado: {len(klingt_sin_dup) + len(dataset_norm)}")
# Out:
# klingt sin duplicados: 902
# dataset: 376
# total combinado: 1278

# %%
venues = pd.read_csv('venues.csv', sep=',', encoding='utf-8-sig', usecols=['Venue', 'Bezirk'])
venues['venue_norm'] = venues['Venue'].str.lower().str.strip()

klingt_sin_dup = klingt_sin_dup.merge(venues[['venue_norm', 'Bezirk']], on='venue_norm', how='left')

combinado = pd.concat([
    dataset_norm[['venue_norm', 'Bezirk']],
    klingt_sin_dup[['venue_norm', 'Bezirk']]
])

print(combinado.groupby('Bezirk').size().sort_values(ascending=False))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 venues = pd.read_csv('venues.csv', sep=',', encoding='utf-8-sig', usecols=['Venue', 'Bezirk'])
#       2 venues['venue_norm'] = venues['Venue'].str.lower().str.strip()
#       4 klingt_sin_dup = klingt_sin_dup.merge(venues[['venue_norm', 'Bezirk']], on='venue_norm', how='left')
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1898, in TextFileReader._make_engine(self, f, engine)
#    1895     raise ValueError(msg)
#    1897 try:
# -> 1898     return mapping[engine](f, **self.options)
#    1899 except Exception:
#    1900     if self.handles is not None:
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:140, in CParserWrapper.__init__(self, src, **kwds)
#     136 assert self.orig_names is not None
#     137 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     138     self.orig_names
#     139 ):
# --> 140     self._validate_usecols_names(usecols, self.orig_names)
#     142 # error: Cannot determine type of 'names'
#     143 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     144     # error: Cannot determine type of 'names'
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/site-packages/pandas/io/parsers/base_parser.py:988, in ParserBase._validate_usecols_names(self, usecols, names)
#     986 missing = [c for c in usecols if c not in names]
#     987 if len(missing) > 0:
# --> 988     raise ValueError(
#     989         f"Usecols do not match columns, columns expected but not found: "
#     990         f"{missing}"
#     991     )
#     993 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['Venue', 'Bezirk']

# %%
venues = pd.read_csv('venues.csv', sep=',', encoding='utf-8-sig')
print(venues.columns.tolist())
# Out:
# ['Venue\tAdresse\tBezirk\tProgrammprofil\tWebsite\tlat\tlon\tKlassifiezierung\tAnmerkungen\tStatus']

# %%
venues = pd.read_csv('venues.csv', sep='\t', encoding='utf-8-sig', usecols=['Venue', 'Bezirk'])
venues['venue_norm'] = venues['Venue'].str.lower().str.strip()

klingt_sin_dup = klingt_sin_dup.merge(venues[['venue_norm', 'Bezirk']], on='venue_norm', how='left')

combinado = pd.concat([
    dataset_norm[['venue_norm', 'Bezirk']],
    klingt_sin_dup[['venue_norm', 'Bezirk']]
])

print(combinado.groupby('Bezirk').size().sort_values(ascending=False))
# Out:
# Bezirk
# 6                     235
# 15                    224
# 17                     91
# 1                      88
# 3                      70
# 1                      62
# 2                      47
# 8                      43
# 7                      42
# 9                      39
# 8                      37
# 12                     35
# 2                      34
# 17                     32
# 9                      29
# 7                      23
# 18                     21
# 15                     19
# 5                      18
# 3                      15
# 16                     14
# 12                     12
# 6                       8
# 19                      7
# 22                      5
# 14                      5
# 14                      4
# 11                      3
# 20                      3
# 4                       3
# [kein Bezirk]           3
# 18                      2
# [nicht öffentlich]      2
# 20                      1
# 10                      1
# 11                      1
# dtype: int64

# %%
combinado['Bezirk'] = combinado['Bezirk'].astype(str).str.strip()
print(combinado.groupby('Bezirk').size().sort_values(ascending=False))
# Out:
# Bezirk
# 6                     243
# 15                    243
# 1                     150
# 17                    123
# 3                      85
# 2                      81
# 8                      80
# 9                      68
# 7                      65
# 12                     47
# 18                     23
# 5                      18
# 16                     14
# 14                      9
# 19                      7
# 22                      5
# 20                      4
# 11                      4
# 4                       3
# [kein Bezirk]           3
# [nicht öffentlich]      2
# 10                      1
# dtype: int64
